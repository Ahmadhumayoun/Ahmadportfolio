# %%
import pandas as pd

# %%
csvChec= pd.read_csv("FinalItems.csv")

# %%
csvChec
# Out:
#                                                  Picture      Id  \
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177
# ...                                                  ...     ...
# 24781  67    https://www.storeakmedia.com/storeak-erp...  361770
# 24782  67    https://www.storeakmedia.com/storeak-erp...  361770
# 24783  67    https://www.storeakmedia.com/storeak-erp...  361770
# 24784  67    https://www.storeakmedia.com/storeak-erp...  361770
# 24785  67    https://www.storeakmedia.com/storeak-erp...  361770
#
#                                             Arabic Names  \
# 0                             زيت الشفاه بليجر 001، 5 مل
# 1                   عطر بلو دي شانيل لي اكسكلوسيف الجديد
# ...
